# %%
import numpy as np
import cv2
from collections import defaultdict
from dataclasses import dataclass, field
import pickle
import os
from pathlib import Path
from tqdm import tqdm
import time
import joblib
# --- Optional FAISS for faster/more robust k-means ---
try:
    import faiss  # pip install faiss-cpu  (or faiss-gpu)
    FAISS_AVAILABLE = True
except Exception:
    faiss = None
    FAISS_AVAILABLE = False

# %%
# ---------- Feature Extraction ----------
def extract_sift(gray_img, nfeatures=500):
    sift = cv2.SIFT_create(nfeatures=nfeatures)
    kps, desc = sift.detectAndCompute(gray_img, None)
    if desc is None:
        return np.empty((0,128), np.float32), []
    return desc.astype(np.float32), kps
def to_rootsift(desc, eps=1e-12, l2_after=True):
    """
    Convert SIFT -> RootSIFT (Arandjelović & Zisserman, 2012).
    Steps: L1-normalize, then sqrt. Optionally L2-normalize after sqrt.
    desc: (N,128) float32
    """
    if desc is None or len(desc) == 0:
        return np.empty((0,128), np.float32)
    # L1-normalize
    desc /= (np.sum(desc, axis=1, keepdims=True) + eps)
    # element-wise sqrt
    desc = np.sqrt(desc, dtype=np.float32)
    if l2_after:
        # optional: stabilize numerics
        norms = np.linalg.norm(desc, axis=1, keepdims=True) + eps
        desc /= norms
    return desc.astype(np.float32)

# %%
def keypoints_to_tuples(kps):
    return [(kp.pt[0], kp.pt[1], kp.size, kp.angle, kp.response, kp.octave, kp.class_id)
            for kp in kps]

# %%
@dataclass
class VocabNode:
    centroid: np.ndarray
    children: list = field(default_factory=list)
    is_leaf: bool = False
    node_id: int = -1  # unique id for all nodes; leaves get final "visual word" ids
    df: int = 0        # document frequency (images that hit this node)
    idf: float = 0.0   # computed after training
    # optional: entropy if you prefer that formulation

# %%
import faiss
import numpy as np

# ---------- Hierarchical K-means (Vocabulary Tree) ----------
class VocabTree:
    def __init__(self, k=10, L=6, min_cluster_size=30, max_iter=20, seed=0):
        self.k = int(k)
        self.L = int(L)
        self.min_cluster_size = int(min_cluster_size)
        self.max_iter = int(max_iter)
        self.rng = np.random.RandomState(seed)
        self.root = None
        self.leaf_nodes = []   # populated after build
        self._next_id = 0
        # If elsewhere you build a compact id map: self.leaf_id_map = {leaf.node_id: i, ...}

    # ---- FAISS KMeans ----
    def _kmeans(self, X, k):
        X = np.ascontiguousarray(X.astype(np.float32))
        N, D = X.shape
        if N < k:
            k = max(1, N)
        seed = int(self.rng.randint(0, 2**31 - 1))
        clus = faiss.Kmeans(d=D, k=k, niter=50, nredo=3, verbose=True, seed=seed)
        try:
            if hasattr(faiss, "get_num_gpus") and faiss.get_num_gpus() > 0 and hasattr(clus, "gpu"):
                clus.gpu = True
        except Exception:
            pass
        clus.train(X)
        centroids = np.ascontiguousarray(clus.centroids.reshape(k, D))
        index = faiss.IndexFlatL2(D); index.add(centroids)
        _, I = index.search(X, 1)
        return centroids, I.ravel().astype(np.int32)


    def _build_rec(self, X, level):
        node = VocabNode(centroid=X.mean(0), node_id=self._next_id)
        self._next_id += 1
        
         # FAISS-aware early stop
        required = max(self.min_cluster_size, 39 * self.k)
        if level == self.L or len(X) < required:
            node.is_leaf = True
            self.leaf_nodes.append(node)
            return node


        centroids, labels = self._kmeans(X, self.k)
        for j in range(centroids.shape[0]):
            child_points = X[labels == j]
            if len(child_points) == 0:
                continue
            child = self._build_rec(child_points, level + 1)
            child.centroid = centroids[j]
            node.children.append(child)
        if len(node.children) == 0:
            node.is_leaf = True
            self.leaf_nodes.append(node)
        return node

    def fit(self, all_descs):
        """
        all_descs: list of np.ndarray, each (Ni, D) SIFT/RootSIFT descriptors per image.
        """
        X = np.vstack([d for d in all_descs if len(d)])
        print("Training descriptors:", len(X))
        self.root = self._build_rec(X, level=0)

    # ---- Hard (single-path) assignment, unchanged ----
    def quantize_path(self, desc):
        """
        Return the leaf node reached by this descriptor (hard assignment).
        """
        node = self.root
        while not node.is_leaf and node.children:
            # pick child with nearest centroid
            cents = np.stack([ch.centroid for ch in node.children], axis=0)
            j = int(np.argmin(((cents - desc) ** 2).sum(1)))
            node = node.children[j]
        return node

    # ---- Soft assignment (new): descend to multiple children when close ----
    def quantize_descriptor_soft(self, desc, ratio=1.15, max_branch=2, max_soft_levels=2):
        """
        Descend the tree allowing up to `max_branch` children per level if their
        distance is within `ratio` of the best distance. Only apply this for the
        first `max_soft_levels` levels; afterwards use single best child.
        Returns a list of *leaf nodes* reached (deduplicated).
        """
        assert self.root is not None
        stack = [(self.root, 0)]
        leaves = []

        while stack:
            node, depth = stack.pop()
            if node.is_leaf or not node.children:
                leaves.append(node)
                continue

            cents = np.stack([c.centroid for c in node.children], axis=0)
            dist = ((cents - desc) ** 2).sum(1)
            order = np.argsort(dist)

            if depth < max_soft_levels:
                best = dist[order[0]]
                chosen = [node.children[i]
                          for i in order
                          if dist[i] <= best * ratio][:max_branch]
            else:
                chosen = [node.children[int(order[0])]]

            for ch in chosen:
                stack.append((ch, depth + 1))

        # Deduplicate in case multiple paths converge to the same leaf
        uniq = {}
        for lf in leaves:
            uniq[lf.node_id] = lf
        return list(uniq.values())

    def quantize_descriptors_soft(self, D, **kwargs):
        """
        Quantize many descriptors with soft assignment,
        returning a list of leaf node_ids (or compact ids if you map them outside).
        """
        if D is None or len(D) == 0:
            return []
        lids = []
        for d in D:
            leaf_nodes = self.quantize_descriptor_soft(d, **kwargs)
            lids.extend([lf.node_id for lf in leaf_nodes])
        return lids

# %%
import numpy as np
from collections import defaultdict
import math

class InvertedIndex:
    """
    Dense-by-leaf postings: postings[leaf_id] is a list of (doc_id, tf).
    IDF is a NumPy array of length num_leaves.
    External IDs are mapped to compact internal doc_ids.
    """
    def __init__(self, num_leaves: int):
        self.num_leaves = int(num_leaves)
        self.postings = [list() for _ in range(self.num_leaves)]  # leaf_id -> [(doc_id, tf)]
        self.doc_tf = {}                   # doc_id(int) -> {leaf_id(int): tf(int)}
        self.idf = np.zeros((self.num_leaves,), dtype=np.float32)
        self.doc_norm = {}                 # doc_id -> L2 norm of TF-IDF vector
        self.N = 0                         # number of docs

        # external<->internal mapping (kept)
        self.ext2int = {}                  # external image_id (str/int) -> doc_id (int)
        self.int2ext = []                  # index = doc_id, value = external id

        # stopwords (optional)
        self.stop_leaves = set()

    # ---------- ID mapping ----------
    def _get_doc_id(self, image_id):
        if image_id in self.ext2int:
            return self.ext2int[image_id]
        doc_id = len(self.int2ext)
        self.ext2int[image_id] = doc_id
        self.int2ext.append(image_id)
        return doc_id

    # ---------- Add one image's TF ----------
    def add_image(self, image_id, leaf_ids):
        """
        leaf_ids MUST be compact leaf IDs in [0..num_leaves-1].
        """
        doc_id = self._get_doc_id(image_id)
        if leaf_ids is None or len(leaf_ids) == 0:
            self.doc_tf[doc_id] = {}
        else:
            uniq, counts = np.unique(np.asarray(leaf_ids, dtype=np.int64), return_counts=True)
            # safety: clip to valid range
            uniq = uniq[(uniq >= 0) & (uniq < self.num_leaves)]
            counts = counts[:len(uniq)]
            self.doc_tf[doc_id] = {int(w): int(c) for w, c in zip(uniq, counts)}
        self.N = len(self.doc_tf)

    # ---------- Build postings from doc_tf (call before compute_idf) ----------
    def _build_postings(self):
        self.postings = [list() for _ in range(self.num_leaves)]
        for doc_id, tfmap in self.doc_tf.items():
            for lid, tf in tfmap.items():
                # skip stop leaves if already defined pre-IDF (rare)
                if lid in self.stop_leaves:
                    continue
                self.postings[lid].append((doc_id, tf))

    # ---------- Choose stop leaves (optional) ----------
    def _choose_stop_leaves(self, top_percent=0.0, frac_thresh=None):
        if (top_percent is None or top_percent <= 0.0) and (frac_thresh is None):
            self.stop_leaves = set()
            return
        df = np.array([len(plist) for plist in self.postings], dtype=np.int32)
        N = max(1, self.N)
        stops = set()
        if top_percent and top_percent > 0.0:
            k = max(1, int(self.num_leaves * top_percent))
            top_idx = np.argpartition(df, -k)[-k:]
            stops.update(int(i) for i in top_idx.tolist())
        if frac_thresh is not None:
            for lid, d in enumerate(df):
                if d / N > frac_thresh:
                    stops.add(lid)
        self.stop_leaves = stops

    # ---------- Compute IDF (after postings are built) ----------
    def compute_idf(self, use_entropy=False, stop_percent=0.0, stop_frac=None, hard_purge=False):
        """
        Computes IDF (or entropy weights). Supports optional stopwords:
          - stop_percent: drop top p fraction of most frequent leaves (e.g., 0.005 for 0.5%)
          - stop_frac: drop leaves with df/N > stop_frac (e.g., 0.05)
          - hard_purge: if True, also purge their postings
        """
        # rebuild postings from doc_tf to be sure they're aligned with current docs
        self._build_postings()

        # choose stop leaves (optional)
        self._choose_stop_leaves(top_percent=stop_percent, frac_thresh=stop_frac)
        if hard_purge and self.stop_leaves:
            for lid in self.stop_leaves:
                self.postings[lid] = []

        N = max(1, self.N)
        idf = np.zeros((self.num_leaves,), dtype=np.float32)
        for lid, plist in enumerate(self.postings):
            if lid in self.stop_leaves:
                idf[lid] = 0.0
                continue
            df = len(plist)
            if df == 0:
                idf[lid] = 0.0
            else:
                if use_entropy:
                    p = min(1 - 1e-12, max(1e-12, df / N))
                    idf[lid] = float(-(p * math.log(p) + (1 - p) * math.log(1 - p)))
                else:
                    idf[lid] = float(math.log(N / df))
        self.idf = idf

        # precompute per-doc norms for cosine similarity
        self.doc_norm = {}
        for doc_id, tfmap in self.doc_tf.items():
            s = 0.0
            for lid, tf in tfmap.items():
                w = tf * self.idf[lid]
                s += w * w
            self.doc_norm[doc_id] = math.sqrt(s) if s > 0 else 1.0

    # ---------- Build vectors ----------
    def image_vector(self, image_id):
        """Return normalized TF-IDF vector as dict {leaf_id: weight} using EXTERNAL image_id."""
        if image_id not in self.ext2int:
            return {}
        doc_id = self.ext2int[image_id]
        tf_map = self.doc_tf.get(doc_id, {})
        if not tf_map:
            return {}
        w = {lid: tf * float(self.idf[lid]) for lid, tf in tf_map.items() if self.idf[lid] > 0.0}
        norm = self.doc_norm.get(doc_id, None)
        if norm is None:
            # fallback compute norm if not cached
            s = sum(v * v for v in w.values())
            norm = math.sqrt(s) if s > 0 else 1.0
        if norm == 0:
            norm = 1.0
        return {lid: v / norm for lid, v in w.items()}

    def query_vector(self, leaf_ids):
        tf = defaultdict(int)
        for lid in leaf_ids:
            if 0 <= lid < self.num_leaves and self.idf[lid] > 0.0:
                tf[lid] += 1
        if not tf:
            return {}
        w = {lid: c * float(self.idf[lid]) for lid, c in tf.items()}
        s = sum(v * v for v in w.values())
        norm = math.sqrt(s) if s > 0 else 1.0
        return {lid: v / norm for lid, v in w.items()}

    # ---------- Scoring ----------
    def score(self, qvec, topk=50, return_external_ids=True):
        """
        Cosine similarity via sparse postings. Assumes doc_norms are precomputed.
        Returns [(doc_id or external_id, score), ...]
        """
        if not qvec:
            return []
        acc = defaultdict(float)
        for lid, qw in qvec.items():
            if self.idf[lid] == 0.0:
                continue
            for doc_id, tf in self.postings[lid]:
                iw = tf * float(self.idf[lid])
                acc[doc_id] += qw * iw

        results = []
        for doc_id, dot in acc.items():
            denom = self.doc_norm.get(doc_id, 1.0)
            results.append((doc_id, dot / denom if denom > 0 else 0.0))
        results.sort(key=lambda x: x[1], reverse=True)
        results = results[:topk]
        if return_external_ids:
            return [(self.int2ext[doc_id], score) for doc_id, score in results]
        return results

# %%
# ---------- Putting it together ----------
class VocabTreeDB:
    def __init__(self, k=10, L=6, min_cluster_size=25, max_iter=40, seed=0):
        self.tree = VocabTree(k=k, L=L, min_cluster_size=min_cluster_size, max_iter=max_iter, seed=seed)
        self.index = None
        self.image_meta = {}  # optional: {external_id: {...}}

    def spatial_verify(self, qdesc, qkps, candidates, ratio_thresh=0.75, cap=500, lam=0.001):
        # quick exits
        if qdesc is None or len(qdesc) == 0 or not qkps:
            return [(img_id, score, 0) for img_id, score in candidates]

        qdesc = qdesc.astype(np.float32, copy=False)
        bf = cv2.BFMatcher(cv2.NORM_L2)

        reranked = []
        for img_id, base_score in candidates:
            meta = self.image_meta.get(img_id, None)
            if not meta:
                reranked.append((img_id, base_score, 0)); continue

            desc = meta.get('descs', None)
            kps  = meta.get('kps', None)
            if desc is None or len(desc) == 0 or not kps:
                reranked.append((img_id, base_score, 0)); continue

            desc = desc.astype(np.float32, copy=False)

            # k-NN matches (defensive against short lists)
            matches = bf.knnMatch(qdesc, desc, k=2)
            good = []
            for pair in matches[:cap]:
                if len(pair) < 2:     # sometimes only one neighbor exists
                    continue
                m, n = pair
                if n is not None and m.distance < ratio_thresh * n.distance:
                    good.append(m)

            if len(good) < 4:
                reranked.append((img_id, base_score, 0)); continue

            # build correspondence arrays
            src = np.float32([qkps[m.queryIdx].pt for m in good])
            dst = np.float32([kps[m.trainIdx].pt for m in good])

            H, mask = cv2.findHomography(src, dst, cv2.USAC_MAGSAC, 3.0)

            inliers = int(mask.ravel().sum()) if mask is not None else 0

            final = float(base_score) + lam * min(inliers, cap)
            reranked.append((img_id, final, inliers))

        reranked.sort(key=lambda x: x[1], reverse=True)
        return reranked



    def train(self, image_descs):
        """
        image_descs: list of np.ndarray (Ni,128) used to train the vocab.
        After fit, we build a compact leaf-id map and allocate InvertedIndex with num_leaves.
        """
        self.tree.fit(image_descs)
        # compact leaf IDs: node_id -> [0..num_leaves-1]
        self.tree.leaf_id_map = {leaf.node_id: i for i, leaf in enumerate(self.tree.leaves)} \
                                if hasattr(self.tree, "leaves") else \
                                {leaf.node_id: i for i, leaf in enumerate(self.tree.leaf_nodes)}
        num_leaves = len(self.tree.leaves) if hasattr(self.tree, "leaves") else len(self.tree.leaf_nodes)
        self.index = InvertedIndex(num_leaves=num_leaves)

    def add_image(self, external_image_id, descs, kps=None, path=None):
        # get multiple leaves per descriptor for better recall
        raw_leaf_ids = self.tree.quantize_descriptors_soft(
            descs,
            ratio=1.15,
            max_branch=2,
            max_soft_levels=2
        )

        # map raw node_ids -> compact ids
        leaf_ids = [self.tree.leaf_id_map[lid] for lid in raw_leaf_ids]

        self.index.add_image(external_image_id, leaf_ids)
        
        self.image_meta[external_image_id] = dict(path=path, kps=keypoints_to_tuples(kps), descs=descs)


    def finalize(self, use_entropy=False, stop_percent=0.0, stop_frac=None, hard_purge=False):
        """
        Must be called AFTER all add_image() calls.
        Computes IDF (or entropy) and precomputes doc norms.
        Optional stopwords:
        - stop_percent=0.005  -> drop top 0.5% by df
        - stop_frac=0.05      -> drop leaves with df/N > 0.05
        """
        assert self.index is not None, "Index not initialized."
        self.index.compute_idf(use_entropy=use_entropy,
                            stop_percent=stop_percent,
                            stop_frac=stop_frac,
                            hard_purge=hard_purge)

    def query(self, q_descs, topk=20):
        raw_leaf_ids = self.tree.quantize_descriptors_soft(
            q_descs,
            ratio=1.15,
            max_branch=2,
            max_soft_levels=2
        )
        leaf_ids = [self.tree.leaf_id_map[lid] for lid in raw_leaf_ids]

        qvec = self.index.query_vector(leaf_ids)
        return self.index.score(qvec, topk=topk)

# %%
descriptors_list = []
images_descriptors={}
DIR_NAME='images/'
for image_name in tqdm(os.listdir('images')):
    image=cv2.imread(f'{DIR_NAME}{image_name}', cv2.IMREAD_GRAYSCALE)
    # image8bit = cv2.normalize(image_gs, None, 0, 255, cv2.NORM_MINMAX).astype('uint8')
    descriptors, keypoints = extract_sift(image,nfeatures=1000)
    descriptors = to_rootsift(descriptors)
    images_descriptors[image_name.split('.')[0]]={'desc':descriptors,'kps':keypoints,'path':f'{DIR_NAME}{image_name}'}
    descriptors_list.append(descriptors)


# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)
# Out:
# 100%|██████████| 1219/1219 [00:31<00:00, 38.42it/s]

# %%
db=VocabTreeDB(k=10, L=6)
start_time = time.time()
db.image_meta=images_descriptors
db.train(descriptors_list)
end_time = time.time()
# Out:
# Training descriptors: 1219277
# Sampling a subset of 2560 / 1219277 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.17 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=412.979 imbalance=1.298 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=416.064 imbalance=1.395 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=410.142 imbalance=1.091 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 72105 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=401.236 imbalance=1.016 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=399.699 imbalance=1.287 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.11 s, search 0.06 s): objective=399.885 imbalance=1.257 nsplit=0
# Clustering 1665 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=233.134 imbalance=1.345 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=242.374 imbalance=1.603 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=227.813 imbalance=1.113 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 7853 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=402.338 imbalance=1.058 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=399.86 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.05 s): objective=397.908 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Clustering 783 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=78.558 imbalance=1.343 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=75.1767 imbalance=1.240 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=73.55 imbalance=1.104 nsplit=0
# Objective improved: keep new clusters
# Clustering 486 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=55.3618 imbalance=1.476 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=54.985 imbalance=1.290 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=53.9415 imbalance=1.096 nsplit=0
# Objective improved: keep new clusters
# Clustering 967 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=119.702 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=125.514 imbalance=1.242 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=127.207 imbalance=1.252 nsplit=0
# Clustering 1297 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=171.42 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=169.626 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=169.762 imbalance=1.063 nsplit=0
# Clustering 910 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=117.944 imbalance=1.085 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=118.006 imbalance=1.048 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=121.823 imbalance=1.174 nsplit=0
# Clustering 434 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=36.2815 imbalance=1.270 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=37.1014 imbalance=1.428 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=35.9023 imbalance=1.176 nsplit=0
# Objective improved: keep new clusters
# Clustering 1042 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=79.5685 imbalance=1.290 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=79.1043 imbalance=1.218 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=79.8186 imbalance=1.266 nsplit=0
# Clustering 1033 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=89.7886 imbalance=1.696 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=87.5144 imbalance=1.196 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=88.6692 imbalance=1.223 nsplit=0
# Clustering 570 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=55.483 imbalance=1.273 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=56.0854 imbalance=1.432 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=55.5152 imbalance=1.271 nsplit=0
# Clustering 1709 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=93.0182 imbalance=1.323 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.03 s): objective=88.5186 imbalance=1.272 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=87.3907 imbalance=1.257 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 7654 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=359.635 imbalance=1.135 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=358.771 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.05 s): objective=369.432 imbalance=1.222 nsplit=0
# Clustering 610 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=40.6278 imbalance=1.425 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=40.7408 imbalance=1.377 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.05 s): objective=42.412 imbalance=1.161 nsplit=0
# Clustering 1051 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=105.38 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=107.692 imbalance=1.192 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=107.568 imbalance=1.193 nsplit=0
# Clustering 620 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=60.3007 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=59.1332 imbalance=1.157 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=59.1908 imbalance=1.280 nsplit=0
# Clustering 1032 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=146.344 imbalance=1.291 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=145.132 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=145.599 imbalance=1.161 nsplit=0
# Clustering 640 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=34.0727 imbalance=2.077 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=33.7421 imbalance=1.455 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=33.8879 imbalance=1.448 nsplit=0
# Clustering 838 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=97.7997 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=98.7288 imbalance=1.303 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=98.8061 imbalance=1.101 nsplit=0
# Clustering 466 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=49.0285 imbalance=1.408 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=47.9188 imbalance=1.233 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=48.1314 imbalance=1.286 nsplit=0
# Clustering 763 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=80.1148 imbalance=1.520 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=83.2596 imbalance=1.421 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=79.5242 imbalance=1.332 nsplit=0
# Objective improved: keep new clusters
# Clustering 472 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=25.5594 imbalance=1.390 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=25.3793 imbalance=1.374 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=24.9473 imbalance=1.739 nsplit=0
# Objective improved: keep new clusters
# Clustering 1162 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=108.227 imbalance=1.207 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=107.416 imbalance=1.150 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=108.116 imbalance=1.283 nsplit=0
# Sampling a subset of 2560 / 7895 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=193.835 imbalance=1.136 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.04 s): objective=194.188 imbalance=1.135 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.10 s, search 0.06 s): objective=194.138 imbalance=1.209 nsplit=0
# Clustering 891 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=51.9691 imbalance=1.171 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=52.5296 imbalance=1.170 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.04 s): objective=52.0309 imbalance=1.226 nsplit=0
# Clustering 862 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=56.6993 imbalance=1.447 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=55.9455 imbalance=1.240 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.10 s, search 0.05 s): objective=55.7648 imbalance=1.231 nsplit=0
# Objective improved: keep new clusters
# Clustering 831 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=54.9557 imbalance=1.291 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=55.2071 imbalance=1.116 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.11 s, search 0.05 s): objective=54.558 imbalance=1.231 nsplit=0
# Objective improved: keep new clusters
# Clustering 859 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=50.1828 imbalance=1.258 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=49.9623 imbalance=1.218 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=49.6933 imbalance=1.269 nsplit=0
# Objective improved: keep new clusters
# Clustering 775 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=42.7526 imbalance=1.153 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=42.8524 imbalance=1.068 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=42.7759 imbalance=1.101 nsplit=0
# Clustering 852 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=47.5904 imbalance=1.179 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=47.6504 imbalance=1.036 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.11 s, search 0.05 s): objective=47.6019 imbalance=1.096 nsplit=0
# Clustering 444 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.15 s, search 0.08 s): objective=32.5947 imbalance=1.347 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.26 s, search 0.14 s): objective=33.0973 imbalance=1.434 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.31 s, search 0.17 s): objective=33.201 imbalance=1.364 nsplit=0
# Clustering 814 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=46.5222 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=46.4466 imbalance=1.170 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=46.4137 imbalance=1.110 nsplit=0
# Objective improved: keep new clusters
# Clustering 1436 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=77.3897 imbalance=1.223 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=77.167 imbalance=1.418 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=77.1835 imbalance=1.239 nsplit=0
# Sampling a subset of 2560 / 16073 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=218.259 imbalance=1.137 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=218.337 imbalance=1.199 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=218.454 imbalance=1.174 nsplit=0
# Clustering 1115 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=93.2013 imbalance=1.275 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=93.4772 imbalance=1.098 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=93.5487 imbalance=1.110 nsplit=0
# Clustering 511 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=46.0058 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=45.3252 imbalance=1.145 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=45.2306 imbalance=1.102 nsplit=0
# Objective improved: keep new clusters
# Clustering 1750 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=117.307 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=118.273 imbalance=1.163 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.04 s): objective=118.06 imbalance=1.063 nsplit=0
# Clustering 1939 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=109.464 imbalance=1.122 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=109.548 imbalance=1.023 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=109.928 imbalance=1.062 nsplit=0
# Clustering 2252 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=158.971 imbalance=1.020 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=158.522 imbalance=1.051 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=158.697 imbalance=1.041 nsplit=0
# Clustering 1055 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=79.1225 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=78.8877 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=80.0281 imbalance=1.097 nsplit=0
# Clustering 1623 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=121.321 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=120.911 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=121.072 imbalance=1.060 nsplit=0
# Clustering 1302 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=106.061 imbalance=1.135 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=106.304 imbalance=1.369 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=108.056 imbalance=1.129 nsplit=0
# Clustering 1716 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=117.093 imbalance=1.041 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=117.586 imbalance=1.154 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=116.844 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 2810 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=145.695 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=146.21 imbalance=1.017 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=145.61 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 10078 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=236.247 imbalance=1.486 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.05 s): objective=238.029 imbalance=1.431 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.15 s, search 0.07 s): objective=235.93 imbalance=1.323 nsplit=0
# Objective improved: keep new clusters
# Clustering 589 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.16 s, search 0.05 s): objective=51.9295 imbalance=1.276 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.24 s, search 0.10 s): objective=52.4707 imbalance=1.370 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.28 s, search 0.11 s): objective=51.4698 imbalance=1.252 nsplit=0
# Objective improved: keep new clusters
# Clustering 2120 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=144.462 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=144.54 imbalance=1.062 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=144.211 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Clustering 944 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=83.1384 imbalance=1.283 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=82.8075 imbalance=1.371 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=82.0496 imbalance=1.290 nsplit=0
# Objective improved: keep new clusters
# Clustering 623 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=31.3092 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=31.7735 imbalance=1.445 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=31.1013 imbalance=1.172 nsplit=0
# Objective improved: keep new clusters
# Clustering 690 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=65.4695 imbalance=1.129 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=66.2984 imbalance=1.090 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=65.4649 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Clustering 2160 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=132.622 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=132.299 imbalance=1.077 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=132.161 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Clustering 1142 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=91.8813 imbalance=1.280 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=92.0218 imbalance=1.047 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=91.275 imbalance=1.228 nsplit=0
# Objective improved: keep new clusters
# Clustering 739 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=56.9255 imbalance=1.258 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=57.3166 imbalance=1.178 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=57.1524 imbalance=1.133 nsplit=0
# Clustering 845 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=48.5697 imbalance=1.219 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=47.8642 imbalance=1.141 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=48.6046 imbalance=1.160 nsplit=0
# Sampling a subset of 2560 / 9338 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.11 s, search 0.05 s): objective=356.184 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.14 s, search 0.06 s): objective=354.533 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.17 s, search 0.08 s): objective=356.368 imbalance=1.035 nsplit=0
# Clustering 667 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=67.1412 imbalance=1.170 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=67.531 imbalance=1.359 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=68.58 imbalance=1.254 nsplit=0
# Clustering 961 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=93.4681 imbalance=1.215 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=91.8134 imbalance=1.424 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=91.4286 imbalance=1.132 nsplit=0
# Objective improved: keep new clusters
# Clustering 955 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=108.325 imbalance=1.221 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=108.107 imbalance=1.276 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=108.265 imbalance=1.163 nsplit=0
# Clustering 754 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=62.0316 imbalance=1.385 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=61.7428 imbalance=1.418 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=60.3931 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Clustering 875 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=83.2615 imbalance=1.125 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=82.768 imbalance=1.171 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=83.0021 imbalance=1.162 nsplit=0
# Clustering 1168 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=149.382 imbalance=1.140 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=148.503 imbalance=1.128 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.04 s): objective=149.028 imbalance=1.071 nsplit=0
# Clustering 779 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=58.6991 imbalance=1.110 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=59.1436 imbalance=1.095 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=59.814 imbalance=1.123 nsplit=0
# Clustering 1025 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=84.7003 imbalance=1.182 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=85.8652 imbalance=1.125 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=85.0161 imbalance=1.177 nsplit=0
# Clustering 938 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=74.0175 imbalance=1.164 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=78.3968 imbalance=1.342 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=73.1773 imbalance=1.059 nsplit=0
# Objective improved: keep new clusters
# Clustering 1216 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=90.7192 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=91.277 imbalance=1.080 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.19 s, search 0.06 s): objective=91.2503 imbalance=1.133 nsplit=0
# Sampling a subset of 2560 / 4432 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=260.532 imbalance=1.498 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=260.974 imbalance=1.366 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.10 s, search 0.05 s): objective=256.206 imbalance=1.225 nsplit=0
# Objective improved: keep new clusters
# Clustering 668 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=40.8772 imbalance=1.523 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=40.0773 imbalance=1.257 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=40.1465 imbalance=1.469 nsplit=0
# Clustering 390 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=28.9217 imbalance=1.484 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=28.437 imbalance=1.469 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=28.2716 imbalance=1.329 nsplit=0
# Objective improved: keep new clusters
# Clustering 537 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=36.8827 imbalance=1.123 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=36.4123 imbalance=1.249 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=37.3887 imbalance=1.421 nsplit=0
# Clustering 799 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=38.6058 imbalance=1.322 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=38.5827 imbalance=1.260 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=38.4416 imbalance=1.305 nsplit=0
# Objective improved: keep new clusters
# Clustering 716 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=42.9435 imbalance=1.577 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=42.1024 imbalance=1.203 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=42.4843 imbalance=1.185 nsplit=0
# Sampling a subset of 2560 / 5408 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=341.737 imbalance=1.152 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=339.808 imbalance=1.171 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=339.678 imbalance=1.142 nsplit=0
# Objective improved: keep new clusters
# Clustering 870 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=72.0202 imbalance=1.272 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=71.7667 imbalance=1.297 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=72.881 imbalance=1.156 nsplit=0
# Clustering 714 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=69.7786 imbalance=1.512 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=70.0562 imbalance=1.334 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=70.8285 imbalance=1.353 nsplit=0
# Clustering 668 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=72.2356 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=70.9408 imbalance=1.220 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=71.1986 imbalance=1.171 nsplit=0
# Clustering 643 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=66.6619 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=65.8859 imbalance=1.206 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=65.8728 imbalance=1.333 nsplit=0
# Objective improved: keep new clusters
# Clustering 710 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=73.1739 imbalance=1.204 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=72.0494 imbalance=1.170 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=72.3701 imbalance=1.099 nsplit=0
# Clustering 476 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=54.6915 imbalance=1.164 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=55.1811 imbalance=1.293 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=55.418 imbalance=1.276 nsplit=0
# Clustering 399 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=38.112 imbalance=1.259 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=38.2872 imbalance=1.314 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=37.9202 imbalance=1.201 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 131795 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.03 s
# Outer iteration 0 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=416.661 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.11 s, search 0.06 s): objective=414.764 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.15 s, search 0.07 s): objective=417.838 imbalance=1.114 nsplit=0
# Sampling a subset of 2560 / 21060 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=330.259 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=328.599 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.11 s, search 0.05 s): objective=330.807 imbalance=1.109 nsplit=0
# Clustering 2365 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=151.428 imbalance=1.216 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=150.715 imbalance=1.226 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.13 s, search 0.06 s): objective=153.831 imbalance=1.278 nsplit=0
# Clustering 454 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=10.9714 imbalance=1.390 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=10.9665 imbalance=1.495 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=10.9591 imbalance=1.476 nsplit=0
# Objective improved: keep new clusters
# Clustering 401 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=14.3002 imbalance=1.210 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=14.4597 imbalance=1.118 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=14.5316 imbalance=1.154 nsplit=0
# Clustering 1751 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=138.375 imbalance=1.628 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.03 s): objective=139.628 imbalance=1.491 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=138.769 imbalance=1.143 nsplit=0
# Clustering 519 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=12.45 imbalance=1.418 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=12.3048 imbalance=1.390 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=12.1847 imbalance=1.243 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 3161 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=203.501 imbalance=1.115 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=208.504 imbalance=1.064 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.06 s): objective=203.092 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Clustering 460 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=17.1564 imbalance=1.231 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=17.5692 imbalance=1.413 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.04 s): objective=16.9309 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Clustering 494 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=21.1797 imbalance=1.187 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=21.0541 imbalance=1.232 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=20.8264 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Clustering 2283 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=156.563 imbalance=1.241 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=153.884 imbalance=1.099 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.09 s, search 0.05 s): objective=148.99 imbalance=1.153 nsplit=0
# Objective improved: keep new clusters
# Clustering 2472 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=246.742 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
# ...
# Clustering 957 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=36.3302 imbalance=1.282 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=36.2209 imbalance=1.136 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=36.161 imbalance=1.175 nsplit=0
# Objective improved: keep new clusters
# Clustering 1219 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=40.6726 imbalance=1.241 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=40.3826 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=40.4268 imbalance=1.158 nsplit=0
# Clustering 1423 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=60.593 imbalance=1.137 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=60.1204 imbalance=1.214 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=59.847 imbalance=1.292 nsplit=0
# Objective improved: keep new clusters
# Clustering 1293 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=42.7337 imbalance=1.195 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=42.547 imbalance=1.196 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=42.6015 imbalance=1.153 nsplit=0
# Clustering 2269 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=67.4304 imbalance=1.275 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=67.0702 imbalance=1.181 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=67.4419 imbalance=1.064 nsplit=0
# Clustering 1915 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=62.7333 imbalance=1.141 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=63.197 imbalance=1.144 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=62.6717 imbalance=1.099 nsplit=0
# Objective improved: keep new clusters
# Clustering 641 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=21.8791 imbalance=1.252 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=21.7846 imbalance=1.258 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=21.4632 imbalance=1.335 nsplit=0
# Objective improved: keep new clusters
# Clustering 1035 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=47.45 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=48.5033 imbalance=1.290 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=47.5139 imbalance=1.116 nsplit=0
# Sampling a subset of 2560 / 5487 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.04 s, search 0.03 s): objective=317.627 imbalance=1.205 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.08 s, search 0.04 s): objective=310.128 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.11 s, search 0.06 s): objective=312.086 imbalance=1.064 nsplit=0
# Clustering 537 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=27.4571 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=28.1622 imbalance=1.097 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=27.3899 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Clustering 691 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=66.3925 imbalance=1.342 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=66.6973 imbalance=1.641 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=65.9633 imbalance=1.351 nsplit=0
# Objective improved: keep new clusters
# Clustering 527 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=36.6322 imbalance=1.560 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=35.2641 imbalance=1.197 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=35.5662 imbalance=1.222 nsplit=0
# Clustering 523 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=63.8031 imbalance=1.238 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=65.204 imbalance=1.234 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=66.0048 imbalance=1.321 nsplit=0
# Clustering 730 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=47.6578 imbalance=1.353 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.02 s): objective=46.6327 imbalance=1.232 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=46.6568 imbalance=1.297 nsplit=0
# Clustering 504 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=39.7536 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=40.7855 imbalance=1.420 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=40.0179 imbalance=1.167 nsplit=0
# Clustering 520 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=31.4195 imbalance=1.345 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=32.0332 imbalance=1.445 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.03 s): objective=32.3443 imbalance=1.505 nsplit=0
# Clustering 697 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=67.1421 imbalance=1.260 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=66.0993 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=66.254 imbalance=1.086 nsplit=0
# Clustering 429 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=35.0874 imbalance=1.752 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=32.741 imbalance=1.317 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=32.4958 imbalance=1.392 nsplit=0
# Objective improved: keep new clusters
# Sampling a subset of 2560 / 6976 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=219.6 imbalance=1.147 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=219.561 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=221.348 imbalance=1.149 nsplit=0
# Clustering 518 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=46.4246 imbalance=1.116 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=47.223 imbalance=1.162 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.03 s): objective=46.2989 imbalance=1.064 nsplit=0
# Objective improved: keep new clusters
# Clustering 995 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=50.5447 imbalance=1.074 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=50.3664 imbalance=1.125 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=50.3835 imbalance=1.105 nsplit=0
# Clustering 858 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=55.3404 imbalance=1.144 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=55.381 imbalance=1.097 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.06 s, search 0.03 s): objective=55.4552 imbalance=1.106 nsplit=0
# Clustering 1089 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=55.0541 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=55.4738 imbalance=1.079 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=54.9265 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Clustering 830 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.04 s, search 0.01 s): objective=56.798 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.06 s, search 0.02 s): objective=56.7825 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.08 s, search 0.03 s): objective=56.5266 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Clustering 775 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=52.7306 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.04 s, search 0.02 s): objective=53.1099 imbalance=1.109 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=53.3007 imbalance=1.073 nsplit=0
# Clustering 749 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=40.0354 imbalance=1.130 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=39.8714 imbalance=1.159 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=40.1765 imbalance=1.064 nsplit=0
# Clustering 660 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=45.5234 imbalance=1.113 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=46.1603 imbalance=1.366 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=45.7129 imbalance=1.303 nsplit=0
# Sampling a subset of 2560 / 3353 for training
# Clustering 2560 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=275.617 imbalance=1.210 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=276.578 imbalance=1.073 nsplit=0
# Outer iteration 2 / 3
#   Iteration 49 (0.07 s, search 0.04 s): objective=275.189 imbalance=1.116 nsplit=0
# Objective improved: keep new clusters
# Clustering 604 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.02 s, search 0.01 s): objective=32.9931 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=32.961 imbalance=1.217 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=33.0894 imbalance=1.161 nsplit=0
# Clustering 428 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.01 s, search 0.01 s): objective=31.6434 imbalance=1.290 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=31.3543 imbalance=1.155 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 3
#   Iteration 49 (0.05 s, search 0.02 s): objective=31.9356 imbalance=1.330 nsplit=0
# Clustering 442 points in 128D to 10 clusters, redo 3 times, 50 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 3
#   Iteration 49 (0.03 s, search 0.01 s): objective=28.4456 imbalance=1.220 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 /
 1, 4014: 1, 4026: 1, 4035: 1, 4037: 2, 4042: 1, 4045: 4, 4048: 1, 4054: 2, 4059: 1, 4062: 1, 4070: 1, 4084: 1, 4087: 2, 4102: 2, 4103: 1, 4106: 1, 4108: 1, 4110: 2, 4111: 4, 4112: 1, 4125: 1, 4132: 2, 4141: 1, 4144: 1, 4145: 1, 4147: 1, 4153: 1, 4155: 1, 4157: 1, 4164: 2, 4165: 1, 4197: 1, 4208: 1, 4231: 1, 4235: 1, 4244: 1, 4250: 1, 4251: 1, 4262: 1, 4292: 1, 4293: 1, 4297: 2, 4312: 1, 4317: 1, 4320: 1, 4323: 1, 4324: 2, 4342: 1, 4347: 2, 4348: 1, 4354: 1, 4369: 1, 4373: 2, 4374: 3, 4384: 1, 4394: 2, 440 ...

# %%
def patch_spatial_verify_for_tuples(db):
    def _kp_xy(k):
        if hasattr(k, "pt"):            # cv2.KeyPoint
            return k.pt
        if isinstance(k, (tuple, list)) and len(k) >= 2:
            return float(k[0]), float(k[1])
        if isinstance(k, np.ndarray) and k.size >= 2:
            return float(k[0]), float(k[1])
        raise TypeError(f"Unsupported keypoint type: {type(k)}")

    def _sv(qdesc, qkps, candidates, ratio_thresh=0.75, cap=1000, lam=0.01):
        if qdesc is None or len(qdesc) == 0 or not qkps:
            return [(img_id, score, 0) for img_id, score in candidates]

        qdesc = qdesc.astype(np.float32, copy=False)
        bf = cv2.BFMatcher(cv2.NORM_L2)

        reranked = []
        for img_id, base_score in candidates:
            m = db.image_meta.get(img_id, {})
            desc = m.get("descs", None)
            kps  = m.get("kps", None)
            if desc is None or len(desc) == 0 or not kps:
                reranked.append((img_id, base_score, 0)); continue
            desc = desc.astype(np.float32, copy=False)

            matches = bf.knnMatch(qdesc, desc, k=2)
            good = []
            for pair in matches[:cap]:
                if len(pair) < 2: continue
                m1, m2 = pair
                if m2 is not None and m1.distance < ratio_thresh * m2.distance:
                    good.append(m1)

            if len(good) < 4:
                reranked.append((img_id, base_score, 0)); continue

            src = np.float32([_kp_xy(qkps[m1.queryIdx]) for m1 in good])
            dst = np.float32([_kp_xy(kps [m1.trainIdx]) for m1 in good])

            method = getattr(cv2, "USAC_MAGSAC", cv2.RANSAC)
            H, mask = cv2.findHomography(src, dst, method, 3.0)
            inliers = int(mask.ravel().sum()) if mask is not None else 0

            final = float(base_score) + lam * min(inliers, cap)
            reranked.append((img_id, final, inliers))

        reranked.sort(key=lambda x: x[1], reverse=True)
        return reranked

    db.spatial_verify = _sv
    return db
db=patch_spatial_verify_for_tuples(db)

# %%
# Query
q_descs, q_kps = extract_sift(cv2.imread('vase.png', cv2.IMREAD_GRAYSCALE),nfeatures=1500)
qdesc_root = to_rootsift(q_descs)
cands = db.query(q_descs, topk=200)
print(cands)
reranked = db.spatial_verify(qdesc_root,q_kps, cands, ratio_thresh=0.75, cap=1000, lam=0.01)
top10 = [(img, score) for img, score, inl in reranked[:10]]
print("Top 10 after RANSAC re-ranking:", top10)
sv_map = {img:(final,inl) for img,final,inl in reranked}
changes = []
592658407245), ('213722', 0.026874750896708394), ('2047976', 0.0265940155868087), ('2047052', 0.02600651634578284), ('22785879', 0.025688185721757177), ('213876', 0.02563327460566887), ('2050238', 0.025622824138218585), ('2045394', 0.02461965828742232), ('22786175', 0.023467814097004682), ('2047036', 0.02333512504939925), ('2045465', 0.022859540523510444), ('22786085', 0.02255439256125985), ('22786220', 0.0224885761484885), ('22786158', 0.022127532731571847), ('22786114', 0.022046612363394398), ('22786015', 0.021942973499626692), ('22785946', 0.02188853233757448), ('22786028', 0.021886097962701665), ('2045890', 0.021731692315264027), ('22785948', 0.02155879039990695), ('22786017', 0.02149956742001569), ('1698559', 0.021393005931888868), ('2051093', 0.021246555681455902), ('22786025', 0.020473694019416774), ('22785932', 0.02045188300163766), ('2047028', 0.020391734839749067), ('4699564', 0.0203058809434596 ...
# Top 10 after RANSAC re-ranking: [('1699022', 0.5833855332143357), ('4699522', 0.4474074349222656), ('213492', 0.32240785855802817), ('213852', 0.18935597745404023), ('213834', 0.13751695210964307), ('213550', 0.13707541552179814), ('2045994', 0.13139569684384925), ('213937', 0.13007165575155097), ('213836', 0.12795379684970895), ('212686', 0.12755419986130626)]
# any inliers > True
# top deltas: [('1699022', 0.04338553321433564, 54, 0.54), ('213492', 0.03240785855802821, 29, 0.29), ('22786168', 0.010730902647562233, 5, 0.05), ('213550', 0.09707541552179813, 4, 0.04000000000000001), ('4699522', 0.4474074349222656, 0, 0.0)]

# %%
# Query
q_descs, q_kps = extract_sift(cv2.imread('curvyth.png', cv2.IMREAD_GRAYSCALE),nfeatures=1500)
qdesc_root = to_rootsift(q_descs)
cands = db.query(q_descs, topk=200)
print(cands)
reranked = db.spatial_verify(qdesc_root,q_kps, cands, ratio_thresh=0.75, cap=1000, lam=0.01)
top10 = [(img, score) for img, score, inl in reranked[:10]]
print("Top 10 after RANSAC re-ranking:", top10)
sv_map = {img:(final,inl) for img,final,inl in reranked}
changes = []
for img, base in cands:
    final, inl = sv_map[img]
    changes.append((img, base, inl, final-base))
print("any inliers >", any(inl>0 for _,_,inl,_ in changes))
print("top deltas:", sorted(changes, key=lambda x: x[3], reverse=True)[:5])
# Out:
# [('213852', 0.2386451038316182), ('213937', 0.223105193304115), ('213834', 0.18790092240704934), ('213806', 0.16328723475034468), ('213810', 0.15618622910291843), ('213377', 0.14670359459113777), ('213836', 0.14655139109860849), ('213547', 0.14533467932302727), ('213644', 0.14377584713058342), ('213484', 0.14269303048433116), ('213504', 0.14208651780508505), ('2051085', 0.13741527024547734), ('213550', 0.13474090134347483), ('22786040', 0.12486536388532997), ('213848', 0.11690181825467816), ('2045932', 0.11578951460279376), ('2051088', 0.11118092732685393), ('2051204', 0.10800682071553634), ('213501', 0.10664210332426483), ('22786016', 0.10227971312165766), ('2051167', 0.10170880152075037), ('213739', 0.09762199417277077), ('2051171', 0.09586168377519018), ('22785954', 0.094302595548993), ('22786080', 0.08988030471896796), ('2051087', 0.08864499135303683), ('2051108', 0.08455237163233126), ('4699522', 0.08091947801690419), ('213493', 0.07809
# any inliers > True
# top deltas: [('1698480', 0.026706623125917914, 25, 0.25), ('213852', 0.2386451038316182, 0, 0.0), ('213937', 0.223105193304115, 0, 0.0), ('213834', 0.18790092240704934, 0, 0.0), ('213806', 0.16328723475034468, 0, 0.0)]

# %%
# Query
q_descs, q_kps = extract_sift(cv2.imread('stamp.png', cv2.IMREAD_GRAYSCALE),nfeatures=1500)
qdesc_root = to_rootsift(q_descs)
cands = db.query(q_descs, topk=200)
print(cands)
reranked = db.spatial_verify(qdesc_root,q_kps, cands, ratio_thresh=0.75, cap=1000, lam=0.01)
top10 = [(img, score) for img, score, inl in reranked[:10]]
print("Top 10 after RANSAC re-ranking:", top10)
sv_map = {img:(final,inl) for img,final,inl in reranked}
changes = []
for img, base in cands:
    final, inl = sv_map[img]
    changes.append((img, base, inl, final-base))
print("any inliers >", any(inl>0 for _,_,inl,_ in changes))
print("top deltas:", sorted(changes, key=lambda x: x[3], reverse=True)[:5])
# Out:
# [('4699522', 0.5231873487133393), ('212686', 0.28029610883356804), ('1698480', 0.20577230039700803), ('1698482', 0.13248962505228096), ('2050235', 0.12230345284117297), ('2047959', 0.11351778641045801), ('4699518', 0.09733636132985837), ('213385', 0.09546863400942612), ('22786139', 0.08682086399773996), ('2045406', 0.08421716132693793), ('2045394', 0.08027112106124566), ('22785995', 0.07718863928425675), ('2046020', 0.07714859902699012), ('22785910', 0.07124259964602936), ('5551603', 0.06775103273512599), ('2051157', 0.067130537414744), ('2046774', 0.06514991498495248), ('2051204', 0.06350199445537943), ('1699022', 0.06267918334814411), ('2046816', 0.06071920011949484), ('2045994', 0.05941642051849308), ('2051127', 0.059002432355412054), ('2051167', 0.05771648347520428), ('2051084', 0.05615886245981987), ('212688', 0.05579194468797695), ('22786066', 0.054454235914772546), ('22785898', 0.053309600709412264), ('213834', 0.052468800498927055), ('2047039', 0.050307130620516186), ('22786063', 0.0493345259218738), ('1698483', 0.04625345415208636), ('2047017', 0.04587463239049895), ('4699519', 0.04467119871435596), ('7114044', 0.04404867694659751), ('213559', 0.041212267202795465), ('213852', 0.04023407075866485), ('22786112', 0.03995215604922481), ('2051143', 0.03979543366138569), ('22786164', 0.03668360337016726), ('2051192', 0.03544872602610159), ('22785944', 0.03492123231877787), ('2046920', 0.03489903773601162), ('213522', 0.03422000507115117), ('2046053', 0.03404128652366582), ('22785996', 0.03377614444487559), ('2051194', 0.032167653577498984), ('2045857', 0.031918225838100445), ('2051137', 0.03177322117609845), ('22786038', 0.031286722860354485), ('2046028', 0.03117328227564938), ('2050238', 0.030697784903295354), ('2046840', 0.03020039262051635), ('2046806', 0.030067944512663758), ('2046909', 0.03001177235765805), ('2046975', 0.030005242219575536), ('213746', 0.029949244482818202), ('2051129', 0.029787662095576654), ('2046944', 0.029550515906664004), ('22786114', 0.029467940850304474), ('2051108', 0.029343204947239177), ('2051087', 0.029107628083561026), ('2045956', 0.029101658931824124), ('2045554', 0.029032332395576333), ('2047976', 0.029027056702398232), ('7114049', 0.028738491304402217), ('1698557', 0.028660670511899373), ('2046952', 0.02863782753448834), ('22786175', 0.02829600548009666), ('2051116', 0.02827737379825463), ('2051081', 0.027832793138420082), ('2046792', 0.027596485188410184), ('2046930', 0.027353241908853416), ('2046768', 0.02698672027718399), ('2045932', 0.026802854088807775), ('22786041', 0.026760553919073185), ('2046820', 0.026742885541154792), ('2046844', 0.02661691895121829), ('7114031', 0.02623415609814623), ('2046918', 0.026192085893870464), ('4699521', 0.026174586266862167), ('22786044', 0.025867712109267537), ('2045398', 0.0258277756632409), ('2046950', 0.025759556671385637), ('22785983', 0.0257018439436618), ('22786143', 0.025685043782126625), ('5551600', 0.02565995139654421), ('22786144', 0.024963668921194556), ('2046957', 0.024933792787188644), ('22785908', 0.024882904125033422), ('213492', 0.02468371026517019), ('7114020', 0.024552224161770154), ('2045484', 0.024363759309219704), ('4699520', 0.024196941692918538), ('2046793', 0.024051742217621797), ('2046858', 0.02353679600397107), ('2046771', 0.023441687930170256), ('2051168', 0.023261941670655845), ('213505', 0.023054807257189093), ('2045395', 0.02291495575764955), ('2050251', 0.022899376084096756), ('22786040', 0.02289797476444426), ('213377', 0.02284476560386039), ('213803', 0.022106136906264735), ('4699581', 0.022036612617133255), ('22785940', 0.0219360732070815), ('1698556', 0.021920331476392232), ('2045419', 0.021843608159227527), ('2045405', 0.021827275642706426), ('213836', 0.021590081173455147), ('2045559', 0.021208865882275493), ('2046911', 0.02114946160537321), ('2046988', 0.020623391284668353), ('2050281', 0.020486957831694085), ('22786058', 0.020294688243536165), ('4699566', 0.02028139537982964), ('22786002', 0.02014167704942298 ...
# Top 10 after RANSAC re-ranking: [('212686', 3.570296108833568), ('4699522', 0.5231873487133393), ('22785992', 0.27585341056939133), ('1698480', 0.20577230039700803), ('2046950', 0.17575955667138562), ('2051137', 0.16177322117609846), ('4699518', 0.1473363613298584), ('22786139', 0.14682086399773997), ('213385', 0.13546863400942613), ('1698482', 0.13248962505228096)]
# any inliers > True
# top deltas: [('212686', 0.28029610883356804, 329, 3.29), ('22785992', 0.015853410569391317, 26, 0.26), ('2046950', 0.025759556671385637, 15, 0.15), ('2051137', 0.03177322117609845, 13, 0.13), ('4699524', 0.014525577277445252, 11, 0.11000000000000001)]

# %%
# ========= SAVE SIDE (Jupyter) =========
# Save the trained model to a folder (tree + index + meta), converting cv2.KeyPoint to tuples.
# Usage after you finish training/finalizing:
#   save_vt_model(db, out_dir="vocab_db", include_meta=True)

import os, io, gzip, pickle, tempfile
import numpy as np
import cv2

def save_vt_model(db, out_dir, include_meta=True):
    # ---- helpers ----
    def _atomic_write(path, data_bytes):
        os.makedirs(os.path.dirname(path), exist_ok=True)
        with tempfile.NamedTemporaryFile(dir=os.path.dirname(path), delete=False) as tmp:
            tmp.write(data_bytes); tmp.flush(); os.fsync(tmp.fileno())
            tmp_path = tmp.name
        os.replace(tmp_path, path)

    def _bytes_dump_gz(obj) -> bytes:
        buf = io.BytesIO()
        with gzip.GzipFile(fileobj=buf, mode='wb', compresslevel=6) as f:
            pickle.dump(obj, f, protocol=pickle.HIGHEST_PROTOCOL)
        return buf.getvalue()

    def _iter_nodes_preorder(root):
        stack, seen = [root], set()
        while stack:
            n = stack.pop()
            if id(n) in seen: continue
            seen.add(id(n)); yield n
            for c in reversed(getattr(n, "children", []) or []):
                stack.append(c)

    def export_tree_dict(tree):
        assert tree is not None and tree.root is not None, "Tree must be trained."
        nodes = []
        for n in _iter_nodes_preorder(tree.root):
            nodes.append({
                "node_id": int(n.node_id),
                "is_leaf": bool(getattr(n, "is_leaf", False)),
                "centroid": (None if getattr(n, "centroid", None) is None
                             else np.ascontiguousarray(n.centroid, dtype=np.float32)),
                "children_ids": [int(c.node_id) for c in (getattr(n, "children", None) or [])],
            })
        leaf_id_map = getattr(tree, "leaf_id_map", None)
        if leaf_id_map is not None:
            leaf_id_map = {int(k): int(v) for k, v in leaf_id_map.items()}
        return {
            "version": 1,
            "k": int(getattr(tree, "k", 10)),
            "L": int(getattr(tree, "L", 6)),
            "root_id": int(tree.root.node_id),
            "nodes": nodes,
            "leaf_id_map": leaf_id_map,
        }

    def export_index_dict(index):
        assert index is not None, "Index is None; finalize() before saving."
        return {
            "version": 1,
            "num_leaves": int(index.num_leaves),
            "doc_tf": {int(d): {int(w): int(tf) for w, tf in tfmap.items()}
                       for d, tfmap in index.doc_tf.items()},
            "idf": np.ascontiguousarray(index.idf, dtype=np.float32),
            "doc_norm": {int(d): float(v) for d, v in index.doc_norm.items()},
            "N": int(getattr(index, "N", len(index.doc_tf))),
            "ext2int": {k: int(v) for k, v in getattr(index, "ext2int", {}).items()},
            "int2ext": list(getattr(index, "int2ext", [])),
            "stop_leaves": set(getattr(index, "stop_leaves", set())),
        }

    def _kp_to_tuple(kp):
        return (float(kp.pt[0]), float(kp.pt[1]),
                float(kp.size), float(kp.angle),
                float(kp.response), int(kp.octave), int(kp.class_id))

    def export_meta_dict(db, include=True):
        if not include:
            return None
        meta = getattr(db, "image_meta", {}) or {}
        # sanitize kps → tuples to avoid "cannot pickle 'cv2.KeyPoint'"
        clean = {}
        for img_id, m in meta.items():
            kps = m.get("kps", None)
            if kps and len(kps) and isinstance(kps[0], cv2.KeyPoint):
                kps = [_kp_to_tuple(k) for k in kps]
            clean[img_id] = {
                "path": m.get("path"),
                "descs": (np.ascontiguousarray(m.get("descs"), dtype=np.float32)
                          if m.get("descs") is not None else None),
                "kps": kps
            }
        return {"image_meta": clean}

    # ---- save ----
    os.makedirs(out_dir, exist_ok=True)
    tree_dict = export_tree_dict(db.tree)
    idx_dict  = export_index_dict(db.index)
    meta_dict = export_meta_dict(db, include=include_meta)

    _atomic_write(os.path.join(out_dir, "tree.pkl.gz"),  _bytes_dump_gz(tree_dict))
    _atomic_write(os.path.join(out_dir, "index.pkl.gz"), _bytes_dump_gz(idx_dict))
    if meta_dict is not None:
        _atomic_write(os.path.join(out_dir, "meta.pkl.gz"),  _bytes_dump_gz(meta_dict))
    print(f"[save_vt_model] Saved to: {out_dir}")

    
save_vt_model(db, 'vocab_db', include_meta=True)
# Out:
# [save_vt_model] Saved to: vocab_db
